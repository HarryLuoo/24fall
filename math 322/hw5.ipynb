# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import erf

# Parameters
kappa = 1
x0 = 0.2
N = 5  # Number of image terms on each side
t_min, t_max = 0.001, 0.1
x = np.linspace(0, 1, 200)
t = np.linspace(t_min, t_max, 100)
X, T = np.meshgrid(x, t)
U = np.zeros_like(X)

# Compute u(x,t) using truncated series
for n in range(-N, N+1):
    U += (1/np.sqrt(4*np.pi*kappa*T)) * (
        np.exp(-((X - (2*n + x0))**2) / (4*kappa*T)) -
        np.exp(-((X - (2*n - x0))**2) / (4*kappa*T))
    )

# Plotting
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, T, U, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u(x,t)')
ax.set_title('Surface Plot of u(x,t) for t = 0.001 to 0.1')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
# Parameters remain the same
t_min, t_max = 0.1, 0.3
x = np.linspace(0, 1, 200)
t = np.linspace(t_min, t_max, 100)
X, T = np.meshgrid(x, t)
U = np.zeros_like(X)

for n in range(-N, N+1):
    U += (1/np.sqrt(4*np.pi*kappa*T)) * (
        np.exp(-((X - (2*n + x0))**2) / (4*kappa*T)) -
        np.exp(-((X - (2*n - x0))**2) / (4*kappa*T))
    )

# Plotting
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, T, U, cmap='plasma')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u(x,t)')
ax.set_title('Surface Plot of u(x,t) for t = 0.1 to 0.3')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
